# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading in the dataset
df = pd.read_csv("churn.csv")

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
# Understand the data
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
# Setting up the plotting style
sns.set_style(style="whitegrid")
plt.figure(figsize=(12, 10))

# %%
sns.countplot(x="Exited", data=df)
plt.title("Distribution of Churn")
# Out:
# Text(0.5, 1.0, 'Distribution of Churn')

# %%
# Getting a sense of the distribution of customers

# %%
sns.histplot(data=df, x="Age", kde=True)
plt.title("Age Distribution")
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
# Credit score vs Age Scatterplot
sns.scatterplot(data=df, x="CreditScore", y="Age", hue="Exited")
plt.title("Credit Score vs Age")
# Out:
# Text(0.5, 1.0, 'Credit Score vs Age')

# %%
# This doesn't show sa clear separation between chruned and not churned based on credit score and age. We can see there is a higher distribution of older customers that churn.

# %%
# Account balances between customers that churn and those that don't
sns.boxplot(x="Exited", y="Balance", data=df)
plt.title("Balance Distibution by Churn")
# Out:
# Text(0.5, 1.0, 'Balance Distibution by Churn')

# %%
# Customers who have churned seem to have higher account balances vs those that didn't churn.
# Highvalue customers may be at higher risk of leaving

# %%
sns.boxplot(x="Exited", y="CreditScore", data=df)
plt.title("Credit Score Distributions by Churn")
# Out:
# Text(0.5, 1.0, 'Credit Score Distributions by Churn')

# %%
# Preprocessing
# Separate features and target variable

# %%
features = df.drop("Exited", axis=1)

# %%
features
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
target = df['Exited']

# %%
target
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
# Dropping unnessary columns
features = features.drop(["RowNumber", "CustomerId","Surname"], axis=1)

# %%
features
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
# drop rows missing any data
features = features.dropna()

# %%
# Use one hot encoding to convert categorical variables into binary format.
features = pd.get_dummies(features, columns=["Geography", "Gender"])

# %%
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# ...

# %%
# Goal is for the Data set 80% Training Set and 20% testing set

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.15, random_state=42)

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
X_train[0]
# Out:
# array([ 0.22403365, -0.18464223, -1.04122063, -1.21811513, -0.9152861 ,
#         0.64787559,  0.97077967, -1.50783884,  0.99858923, -0.5757201 ,
#        -0.57789366, -0.91381642,  0.91381642])

# %%
X_train[1]
# Out:
# array([ 0.82599563,  0.38431153,  1.38458411,  0.04952734, -0.9152861 ,
#        -1.54350622, -1.03009986, -1.73524149, -1.00141276,  1.73695516,
#        -0.57789366,  1.0943117 , -1.0943117 ])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import pickle #allows saving of models

import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, StackingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

# %%
# linear regression
lr_model = LogisticRegression(random_state=42)

# %%
lr_model.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
# Now that the model is trained it can be used to predict.

# %%
lr_predictions = lr_model.predict(X_test)

# %%
lr_predictions
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
lr_accuracy = accuracy_score(y_test, lr_predictions)

# %%
lr_accuracy
# Out:
# 0.8113333333333334

# %%
# Models: XGBoost, Decision Tree, Random Forest, Naire Bayes, Support Vector Machines, etc.

# %%
# Function to define models and save them.
def evaluate_and_save_model(model, X_train, X_test,y_train, y_test, filename):
  model.fit(X_train, y_train)
  y_pred = model.predict(X_test)
  accuracy = accuracy_score(y_test, y_pred)
  print(f"{model.__class__.__name__} Accuracy: {accuracy:.4f}")
  print(f"\nClassification Report:\n{classification_report(y_test, y_pred)}")
  print("-----------------------------------")

  with open(filename, "wb") as file:
    pickle.dump(model, file)

    print(f"Model saved as {filename}")

# %%
xgb_model = xgb.XGBClassifier(random_state=42)
evaluate_and_save_model(xgb_model, X_train, X_test,y_train, y_test, "xgb_model.pkl")

dt_model = DecisionTreeClassifier(random_state=42)
evaluate_and_save_model(dt_model, X_train, X_test, y_train, y_test, "dt_model.pkl")

rt_model = RandomForestClassifier(random_state=42)
evaluate_and_save_model(rt_model, X_train, X_test, y_train, y_test, "rt_model.pkl")

nb_model = GaussianNB()
evaluate_and_save_model(nb_model, X_train, X_test, y_train, y_test, "nb_model.pkl")

knn_model = KNeighborsClassifier()
evaluate_and_save_model(knn_model, X_train, X_test, y_train, y_test, "knn_model.pkl")

svm_model = SVC(random_state=42)
evaluate_and_save_model(svm_model, X_train, X_test, y_train, y_test, "svm_model.pkl")

# GB
gb_model = GradientBoostingClassifier(random_state=42)
evaluate_and_save_model(gb_model, X_train, X_test, y_train, y_test, "gb_model.pkl")

# Stacking
estimators = [
    ('dt', DecisionTreeClassifier(random_state=42)),
    ('rf', RandomForestClassifier(random_state=42)),
    ('svc', SVC(probability=True, random_state=42))
]
stacking_model = StackingClassifier(
    estimators=estimators,
    final_estimator=LogisticRegression(),
    cv=5
)
evaluate_and_save_model(stacking_model, X_train, X_test, y_train, y_test, "stacking_model.pkl")
# Out:
# XGBClassifier Accuracy: 0.8127
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.89      1207
#            1       0.52      0.46      0.49       293
#
#     accuracy                           0.81      1500
#    macro avg       0.70      0.68      0.69      1500
# weighted avg       0.80      0.81      0.81      1500
#
# -----------------------------------
# Model saved as xgb_model.pkl
# DecisionTreeClassifier Accuracy: 0.7947
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87      1207
#            1       0.48      0.52      0.50       293
#
#     accuracy                           0.79      1500
#    macro avg       0.68      0.69      0.68      1500
# weighted avg       0.80      0.79      0.80      1500
#
# -----------------------------------
# Model saved as dt_model.pkl
# RandomForestClassifier Accuracy: 0.8627
#
# ...

# %%
# Which features are most helful in predicting when a customer is going to churn

# %%
feature_importances = xgb_model.feature_importances_
feature_names = features.columns

# %%
feature_importances
# Out:
# array([0.0344573 , 0.11471547, 0.032618  , 0.05422014, 0.28585926,
#        0.03250625, 0.19245714, 0.03417897, 0.0342634 , 0.10509478,
#        0.03617681, 0.04345243, 0.        ], dtype=float32)

# %%
feature_names
# Out:
# Index(['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Geography_France',
#        'Geography_Germany', 'Geography_Spain', 'Gender_Female', 'Gender_Male'],
#       dtype='object')

# %%
feature_importances_df = pd.DataFrame({
    'feature': feature_names,
    'importance': feature_importances
})

# %%
feature_importances_df
# Out:
#               feature  importance
# 0         CreditScore    0.034457
# 1                 Age    0.114715
# 2              Tenure    0.032618
# 3             Balance    0.054220
# 4       NumOfProducts    0.285859
# 5           HasCrCard    0.032506
# 6      IsActiveMember    0.192457
# 7     EstimatedSalary    0.034179
# 8    Geography_France    0.034263
# 9   Geography_Germany    0.105095
# 10    Geography_Spain    0.036177
# 11      Gender_Female    0.043452
# 12        Gender_Male    0.000000

# %%
feature_importances_df = feature_importances_df.sort_values('importance', ascending=False)

# %%
feature_importances_df
# Out:
#               feature  importance
# 4       NumOfProducts    0.285859
# 6      IsActiveMember    0.192457
# 1                 Age    0.114715
# 9   Geography_Germany    0.105095
# 3             Balance    0.054220
# 11      Gender_Female    0.043452
# 10    Geography_Spain    0.036177
# 0         CreditScore    0.034457
# 8    Geography_France    0.034263
# 7     EstimatedSalary    0.034179
# 2              Tenure    0.032618
# 5           HasCrCard    0.032506
# 12        Gender_Male    0.000000

# %%
plt.figure(figsize=(10, 6))

# %%
plt.figure(figsize=(10, 6))
plt.bar(feature_importances_df['feature'], feature_importances_df['importance'])
plt.xticks(rotation=90)
plt.xlabel("Features")
plt.ylabel('Importance')
plt.tight_layout()
plt.show()

# %%
# From the above chart we can see the most important features tfor predicting churn are NumOfProducts, IsActiveMember, Age.

# %%
# Ways to improve Model Accuracy. Feature Engineering, SMOTE, Ensembling

# %%
# Feature Engineering. Creating the Customer Lifetime Value.

# %%
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# ...

# %%
features['CLV'] = df['Balance'] = df['EstimatedSalary'] / 100000

# %%
features['AgeGroup'] = pd.cut(df['Age'], bins=[0, 30, 45, 60, 100], labels=['Young', 'MiddleAge', 'Senior', 'Elderly'])

# %%
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# ...

# %%
features['TenureAgeRatio'] = df['Tenure'] / df['Age']

# %%
# Handle Categorical Values
features = pd.get_dummies(features, drop_first=True)

# %%
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# ...

# %%
# SPlitting into Training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
X_train
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 9254          686   32       6       0.00              2          1
# 1561          632   42       4  119624.60              2          1
# 1670          559   24       3  114739.92              1          1
# 6087          561   27       9  135637.00              1          1
# 6669          517   56       9  142147.32              1          0
# ...           ...  ...     ...        ...            ...        ...
# 5734          768   54       8   69712.74              1          1
# 5191          682   58       1       0.00              1          1
# 5390          735   38       1       0.00              3          0
# 860           667   43       8  190227.46              1          1
# 7270          697   51       1  147910.30              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# ...

# %%
xgboost_model = xgb.XGBClassifier(random_state=42)
evaluate_and_save_model(xgboost_model, X_train, X_test,y_train, y_test, "xgboost-featureEngineered.pkl")
# Out:
# XGBClassifier Accuracy: 0.8665
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92      1607
#            1       0.73      0.51      0.60       393
#
#     accuracy                           0.87      2000
#    macro avg       0.81      0.73      0.76      2000
# weighted avg       0.86      0.87      0.86      2000
#
# -----------------------------------
# Model saved as xgboost-featureEngineered.pkl

# %%
# SMOTE
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(random_state=42)

# %%
X_resampled, y_resampled = smote.fit_resample(X_train,y_train)

# %%
evaluate_and_save_model(xgboost_model, X_resampled, X_test, y_resampled, y_test, 'xgboost-SMOTE.pkl')
# Out:
# XGBClassifier Accuracy: 0.8575
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      1607
#            1       0.67      0.55      0.60       393
#
#     accuracy                           0.86      2000
#    macro avg       0.78      0.74      0.76      2000
# weighted avg       0.85      0.86      0.85      2000
#
# -----------------------------------
# Model saved as xgboost-SMOTE.pkl

# %%
# Best model trained so far.

# %%
# Ensembling using a voting classifier
from sklearn.ensemble import VotingClassifier

# %%
voting_clf = VotingClassifier(
    estimators = [('xgboost', xgb.XGBClassifier(random_state=42)), ('rf', RandomForestClassifier(random_state=42)), ('svm', SVC(random_state=42, probability=True))],
    voting='hard'
)

# %%
evaluate_and_save_model(voting_clf, X_resampled, X_test, y_resampled, y_test, 'voting_clf.pkl')
# Out:
# VotingClassifier Accuracy: 0.8590
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.93      0.91      1607
#            1       0.66      0.58      0.62       393
#
#     accuracy                           0.86      2000
#    macro avg       0.78      0.75      0.77      2000
# weighted avg       0.85      0.86      0.86      2000
#
# -----------------------------------
# Model saved as voting_clf.pkl

# %%
# TD: trying different models and see if I cna get an improved results.
